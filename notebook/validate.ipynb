# %%
import pandas as pd

# %%
df= pd.read_csv("/config/workspace/artifact/04022023__092421/data_ingestion/dataset/train.csv")

# %%
drop_column_names=[]
for column_name, missing_percantage in zip((df.isnull().sum()/df.shape[0]).index, (df.isnull().sum()/df.shape[0]).values):
    print(column_name,missing_percantage*100)
    if missing_percantage>0.3:
        drop_column_names.append(column_name)
# Out:
# class 0.0
# aa_000 0.0
# ab_000 77.12607944732297
# ac_000 6.0310880829015545
# ad_000 25.450777202072537
# ae_000 4.4835924006908465
# af_000 4.4835924006908465
# ag_000 1.063903281519862
# ag_001 1.063903281519862
# ag_002 1.063903281519862
# ag_003 1.063903281519862
# ag_004 1.063903281519862
# ag_005 1.063903281519862
# ag_006 1.063903281519862
# ag_007 1.063903281519862
# ag_008 1.063903281519862
# ag_009 1.063903281519862
# ah_000 1.0846286701208983
# ai_000 1.060449050086356
# aj_000 1.060449050086356
# ak_000 7.76511226252159
# al_000 1.077720207253886
# am_0 1.060449050086356
# an_000 1.077720207253886
# ao_000 0.9775474956822107
# ap_000 1.077720207253886
# aq_000 0.9775474956822107
# ar_000 4.8739205526770295
# as_000 1.060449050086356
# at_000 1.060449050086356
# au_000 1.060449050086356
# av_000 4.487046632124352
# ax_000 4.487046632124352
# ay_000 1.063903281519862
# ay_001 1.063903281519862
# ay_002 1.063903281519862
# ay_003 1.063903281519862
# ...

# %%
drop_column_names
# Out:
# ['ab_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'cr_000']

# %%
null_report =df.isna().sum()/df.shape[0]
null_report[null_report>0.3].index

# %%
# Out:
# Index(['ab_000', 'bk_000', 'bl_000', 'bm_000', 'bn_000', 'bo_000', 'bp_000',
#        'bq_000', 'br_000', 'cr_000'],
#       dtype='object')
